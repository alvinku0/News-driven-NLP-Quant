# %%
import requests
url='https://www.alphavantage.co/query?function=NEWS_SENTIMENT&tickers=AAPL&apikey=demo'
data=requests.get(url).json()
print(data)
# Out:
# {'items': '50', 'sentiment_score_definition': 'x <= -0.35: Bearish; -0.35 < x <= -0.15: Somewhat-Bearish; -0.15 < x < 0.15: Neutral; 0.15 <= x < 0.35: Somewhat_Bullish; x >= 0.35: Bullish', 'relevance_score_definition': '0 < x <= 1, with a higher score indicating higher relevance.', 'feed': [{'title': 'How High Or Low Can The SPY Go Today? - SPDR S&P 500  ( ARCA:SPY ) ', 'url': 'https://www.benzinga.com/markets/equities/25/03/44435576/how-high-or-low-can-the-spy-go-today', 'time_published': '20250321T130627', 'authors': ['RIPS'], 'summary': "Good Morning Traders! In today's Market Clubhouse Morning Memo, we will discuss SPY, QQQ, AAPL, MSFT, NVDA, GOOGL, META, and TSLA. Our proprietary formula, exclusive to Market Clubhouse, dictates these price levels. This dynamic equation takes into account price, volume, and options flow.", 'banner_image': 'https://www.benzinga.com/next-assets/images/schema-image-default.png', 'source': 'Benzinga', 'category_within_source': 'Trading', 'source_domain': 'www.benzinga.com', 'topics': [{'topic': 'Technology', 'relevance_score': '0.5'}, {'topic': 'Financial Markets', 'relevance_score': '0.996023'}, {'topic': 'Manufacturing', 'relevance_score': '0.5'}], 'overall_sentiment_score': 0.158664, 'overall_sentiment_label': 'Somewhat-Bullish', 'ticker_sentiment': [{'ticker': 'MSFT', 'relevance_score': '0.054421', 'ticker_sentiment_score': '0.296028', 'ticker_sentiment_label': 'Somewhat-Bullish'}, {'ticker': 'GOOG', 'relevance_score': '0.027226', 'ticker_sentiment_score': '0.073351', 'ticker_sentiment_label': 'Neutral'}, {'ticker': 'NVDA', 'relevance_score': '0.081552', 'ticker_sentiment_score': '0.24947', 'ticker_sentiment_label': 'Somewhat-Bullish'}, {'ticker': 'AAPL', 'relevance_score': '0.054421', 'ticker_sentiment_score': '-0.150479', 'ticker_sentiment_label': 'Somewhat-Bearish'}, {'ticker': 'TSLA', 'relevance_score': '0.162255', 'ticker_sentiment_score': '-0.002973', 'ticker_sentiment_label': 'Neutral'}]}, {'title': 'Jeff Bezos And Nvidia-Backed Perplexity AI Eyes $18 Billion Valuation In New Funding Round - Doubling In Just 4 Months - Apple  ( NASDAQ:AAPL ) , Amazon.com  ( NASDAQ:AMZN ) ', 'url': 'https://www.benzinga.com/25/03/44432846/backed-by-jeff-bezos-and-nvidia-perplexity-ai-eyes-18-billion-valuation-in-new-funding-rounddoubling-in-just-4-mo', 'time_published': '20250321T103933', 'authors': ['Ananya Gairola'], 'summary': 'Perplexity, backed by Amazon.com Inc. AMZN founder Jeff Bezos and Nvidia Corp. NVDA is reportedly in talks to raise up to $1 billion in a new funding round that would value the company at $18 billion-double its valuation just four months ago.', 'banner_image': 'https://cdn.benzinga.com/files/images/story/2025/03/21/Perplexity-AI.jpeg?width=1200&height=800&fit=crop', 'source': 'Benzinga', 'category_within_source': 'News', 'source_domain': 'www.benzinga.com', 'topics': [{'topic': 'Technology', 'relevance_score': '0.5'}, {'topic': 'Financial Markets', 'relevance_score': '0.108179'}, {'topic': 'Manufacturing', 'relevance_score': '0.5'}], 'overall_sentiment_score': 0.201451, 'overall_sentiment_label': 'Somewhat-Bullish', 'ticker_sentiment': [{'ticker': 'NVDA', 'relevance_score': '0.235823', 'ticker_sentiment_score': '0.144193', 'ticker_sentiment_label': 'Neutral'}, {'ticker': 'AAPL', 'relevance_score': '0.235823', 'ticker_sentiment_score': '-0.106846', 'ticker_sentiment_label': 'Neutral'}, {'ticker': 'NWSAL', 'relevance_score': '0.119235', 'ticker_sentiment_score': '-0.008176', 'ticker_sentiment_label': 'Neutral'}, {'ticker': 'SFBQF', 'relevance_score': '0.119235', 'ticker_sentiment_score': '0.272539', 'ticker_sentiment_label': 'Somewhat-Bullish'}, {'ticker': 'SFTBF', 'relevance_score': '0.235823', 'ticker_sentiment_score': '0.410304', 'ticker_sentiment_label': 'Bullish'}]}, {'title': 'Is Schwab Fundamental U.S. Large Company ETF  ( FNDX )  a Strong ETF Right Now?', 'url': 'https://www.zacks.com/stock/news/2433207/is-schwab-fundamental-us-large-company-etf-fndx-a-strong-etf-rig ...

# %%
import pprint
pp=pprint.PrettyPrinter()
pp.pprint(data)
# Out:
# {'feed': [{'authors': ['RIPS'],
#            'banner_image': 'https://www.benzinga.com/next-assets/images/schema-image-default.png',
#            'category_within_source': 'Trading',
#            'overall_sentiment_label': 'Somewhat-Bullish',
#            'overall_sentiment_score': 0.158664,
#            'source': 'Benzinga',
#            'source_domain': 'www.benzinga.com',
#            'summary': "Good Morning Traders! In today's Market Clubhouse "
#                       'Morning Memo, we will discuss SPY, QQQ, AAPL, MSFT, '
#                       'NVDA, GOOGL, META, and TSLA. Our proprietary formula, '
#                       'exclusive to Market Clubhouse, dictates these price '
#                       'levels. This dynamic equation takes into account price, '
#                       'volume, and options flow.',
#            'ticker_sentiment': [{'relevance_score': '0.054421',
#                                  'ticker': 'MSFT',
#                                  'ticker_sentiment_label': 'Somewhat-Bullish',
#                                  'ticker_sentiment_score': '0.296028'},
#                                 {'relevance_score': '0.027226',
#                                  'ticker': 'GOOG',
#                                  'ticker_sentiment_label': 'Neutral',
#                                  'ticker_sentiment_score': '0.073351'},
#                                 {'relevance_score': '0.081552',
#                                  'ticker': 'NVDA',
#                                  'ticker_sentiment_label': 'Somewhat-Bullish',
#                                  'ticker_sentiment_score': '0.24947'},
#                                 {'relevance_score': '0.054421',
#                                  'ticker': 'AAPL',
#                                  'ticker_sentiment_label': 'Somewhat-Bearish',
#                                  'ticker_sentiment_score': '-0.150479'},
#                                 {'relevance_score': '0.162255',
#                                  'ticker': 'TSLA',
#                                  'ticker_sentiment_label': 'Neutral',
#                                  'ticker_sentiment_score': '-0.002973'}],
#            'time_published': '20250321T130627',
#            'title': 'How High Or Low Can The SPY Go Today? - SPDR S&P 500  ( '
#                     'ARCA:SPY ) ',
#            'topics': [{'relevance_score': '0.5', 'topic': 'Technology'},
#                       {'relevance_score': '0.996023',
#                        'topic': 'Financial Markets'},
#                       {'relevance_score': '0.5', 'topic': 'Manufacturing'}],
#            'url': 'https://www.benzinga.com/markets/equities/25/03/44435576/how-high-or-low-can-the-spy-go-today'},
#           {'authors': ['Ananya Gairola'],
#            'banner_image': 'https://cdn.benzinga.com/files/images/story/2025/03/21/Perplexity-AI.jpeg?width=1200&height=800&fit=crop',
#            'category_within_source': 'News',
#            'overall_sentiment_label': 'Somewhat-Bullish',
#            'overall_sentiment_score': 0.201451,
#            'source': 'Benzinga',
#            'source_domain': 'www.benzinga.com',
#            'summary': 'Perplexity, backed by Amazon.com Inc. AMZN founder Jeff '
#                       'Bezos and Nvidia Corp. NVDA is reportedly in talks to '
#                       'raise up to $1 billion in a new funding round that '
#                       'would value the company at $18 billion-double its '
#                       'valuation just four months ago.',
#            'ticker_sentiment': [{'relevance_score': '0.235823',
#                                  'ticker': 'NVDA',
#                                  'ticker_sentiment_label': 'Neutral',
#                                  'ticker_sentiment_score': '0.144193'},
#                                 {'relevance_score': '0.235823',
#                                  'ticker': 'AAPL',
#                                  'ticker_sentiment_label': 'Neutral',
#                                  'ticker_sentiment_score': '-0.106846'},
#                                 {'relevance_score': '0.119235',
#                                  'ticker': 'NWSAL',
#                                  'ticker_sentiment_label': 'Neutral',
#                                  'ticker_sentiment_score': '-0.008176'},
#                                 {'relevance_score': '0.119235',
#                                  'ticker': 'SFBQF',
#                                  'ticker_sentiment_label': 'Somewhat-Bullish',
#                                  'ticker_sentiment_score': '0.272539'},
#                                 {'relevance_score': '0.235823',
#                                  'ticker': 'SFTBF',
#                                  'ticker_sentiment_label': 'Bullish',
#                                  'ticker_sentiment_score': '0.410304'}],
#            'time_published': '20250321T103933',
#            'title': 'Jeff Bezos And Nvidia-Backed Perplexity AI Eyes $18 '
#                     'Billion Valuation In New Funding Round - Doubling In Just '
#                     '4 Months - Apple  ( NASDAQ:AAPL ) , Amazon.com  ( '
#                     'NASDAQ:AMZN ) ',
#            'topics': [{'relevance_score': '0.5', 'topic': 'Technology'},
#                       {'relevance_score': '0.108179',
#                        'topic': 'Financial Markets'},
#                       {'relevance_score': '0.5', 'topic': 'Manufacturing'}],
#            'url': 'https://www.benzinga.com/25/03/44432846/backed-by-jeff-bezos-and-nvidia-perplexity-ai-eyes-18-billion-valuation-in-new-funding-rounddoubling-in-just-4-mo'},
#           {'authors': ['Zacks Equity Research'],
#            'banner_image': 'https://staticx-tuner.zacks.com/images/default_article_images/default130.jpg',
#            'category_within_source': 'n/a',
#            'overall_sentiment_label': 'Somewhat-Bullish',
#            'overall_sentiment_score': 0.245237,
#            'source': 'Zacks Commentary',
#            'source_domain': 'www.zacks.com',
#            'summary': 'Smart Beta ETF report for ...',
#            'ticker_sentiment': [{'relevance_score': '0.114956',
#                                  'ticker': 'MSFT',
#                                  'ticker_sentiment_label': 'Neutral',
#                                  'ticker_sentiment_score': '-0.022733'},
#                                 {'relevance_score': '0.057628',
#                                  'ticker': 'SCHW',
#                                  'ticker_sentiment_label': 'Neutral',
#                                  'ticker_sentiment_score': '0.079959'},
#                                 {'relevance_score': '0.114956',
#                                  'ticker': 'AAPL',
#                                  'ticker_sentiment_label': 'Neutral',
#                                  'ticker_sentiment_score': '-0.022733'},
#                                 {'relevance_score': '0.057628',
#                                  'ticker': 'BRK-A',
#                                  'ticker_sentiment_label': 'Neutral',
#                                  'ticker_sentiment_score': '-0.020007'}],
#            'time_published': '20250321T102004',
#            'title': 'Is Schwab Fundamental U.S. Large Company ETF  ( FNDX )  a '
#                     'Strong ETF Right Now?',
#            'topics': [{'relevance_score': '0.5', 'topic': 'Technology'},
#                       {'relevance_score': '0.5', 'topic': 'Finance'},
#                       {'relevance_score': '1.0', 'topic': 'Financial Markets'}],
#            'url': 'https://www.zacks.com/stock/news/2433207/is-schwab-fundamental-us-large-company-etf-fndx-a-strong-etf-right-now'},
#           {'authors': ['Zacks Investment Research'],
#            'banner_image': 'https://staticx-tuner.zacks.com/images/articles/main/ad/429.jpg',
#            'category_within_source': 'n/a',
#            'overall_sentiment_label': 'Somewhat-Bullish',
#            'overall_sentiment_score': 0.240622,
#            'source': 'Zacks Commentary',
#            'source_domain': 'www.zacks.com',
#            'summary': 'Apple, Meta Platforms, Chevron, Taylor Devices and GSI '
#                       'Technology are included in this Analyst Blog.',
#            'ticker_sentiment': [{'relevance_score': '0.231332',
#                                  'ticker': 'META',
#                                  'ticker_sentiment_label': 'Somewhat-Bullish',
#                                  'ticker_sentiment_score': '0.291678'},
#                                 {'relevance_score': '0.305058',
#                                  'ticker': 'AAPL',
#                                  'ticker_sentiment_label': 'Somewhat-Bullish',
#                                  'ticker_sentiment_score': '0.167854'},
#                                 {'relevance_score': '0.116914',
#                                  'ticker': 'CVX',
#                                  'ticker_sentiment_label': 'Neutral',
#                                  'ticker_sentiment_score': '0.046872'},
#                                 {'relevance_score': '0.155451',
#                                  'ticker': 'GSIT',
#                                  'ticker_sentiment_label': 'Neutral',
#                                  'ticker_sentiment_score': '0.069841'},
#                                 {'relevance_score': '0.039096',
#                                  'ticker': 'HES',
#                                  'ticker_sentiment_label': 'Neutral',
#                                  'ticker_sentiment_score': '-0.019664'},
#                                 {'relevance_score': '0.193619',
#                                  'ticker': 'TAYD',
#                                  'ticker_sentiment_label': 'Neutral',
#                                  'ticker_sentiment_score': '0.079041'}],
#            'time_published': '20250321T085500',
#            'title': 'The Zacks Analyst Blog Highlights Apple, Meta Platforms, '
#                     'Chevron, Taylor Devices and GSI Technology',
#            'topics': [{'relevance_score': '0.333333', 'topic': 'Manufacturing'},
#                       {'relevance_score': '0.744043', 'topic': 'Earnings'},
#                       {'relevance_score': '0.333333',
#                        'topic': 'Energy & Transportation'},
#                       {'relevance_score': '0.333333', 'topic': 'Technology'}],
#            'url': 'https://www.zacks.com/stock/news/2433175/the-zacks-analyst-blog-highlights-apple-meta-platforms-chevron-taylor-devices-and-gsi-technology'},
#           {'authors': ['Namrata Sen'],
#            'banner_image': 'https://cdn.benzinga.com/files/images/story/2025/03/21/Apple-TV--Photo-by-Ivan-Marc-on-Shutters.jpeg?width=1200&height=800&fit=crop',
#            'category_within_source': 'Markets',
#            'overall_sentiment_label': 'Neutral',
#            'overall_sentiment_score': 0.107822,
#            'source': 'Benzinga',
#            'source_domain': 'www.benzinga.com',
#            'summary': 'The streaming service of Apple Inc. AAPL, Apple TV+, is '
#                       'reportedly incurring annual losses exceeding $1 '
#                       'billion. What Happened: Since its 2019 launch, Apple '
#                       'has been allocating over $5 billion annually to content '
#                       'for Apple TV+. However, this budget was cut by around '
#                       '$500 million last year.',
#            'ticker_sentiment': [{'relevance_score': '0.306963',
#                                  'ticker': 'NFLX',
#                                  'ticker_sentiment_label': 'Neutral',
#                                  'ticker_sentiment_score': '0.051753'},
#                                 {'relevance_score': '0.951582',
#                                  'ticker': 'AAPL',
#                                  'ticker_sentiment_label': 'Neutral',
#                                  'ticker_sentiment_score': '0.145237'},
#                                 {'relevance_score': '0.078611',
#                                  'ticker': 'CCZ',
#                                  'ticker_sentiment_label': 'Neutral',
#                                  'ticker_sentiment_score': '0.102483'}],
#            'time_published': '20250321T064232',
#            'title': 'Apple TV+ Bleeding Over $1 Billion Yearly As Streaming '
#                     'War Heats Up: Report - Apple  ( NASDAQ:AAPL ) , '
#                     'Amazon.com  ( NASDAQ:AMZN ) ',
#            'topics': [{'relevance_score': '0.360215', 'topic': 'Earnings'},
#                       {'relevance_score': '1.0', 'topic': 'Technology'},
#                       {'relevance_score': '0.161647',
#                        'topic': 'Financial Markets'}],
#            'url': 'https://www.benzinga.com/markets/25/03/44430524/apple-tv-bleeding-over-1-billion-yearly-as-streaming-war-heats-up-report'},
#           {'authors': ['Kaustubh Bagalkote'],
#            'banner_image': 'https://cdn.benzinga.com/files/images/story/2025/03/20/Apple-Intelligence.jpeg?width=1200&height=800&fit=crop',
#            'category_within_source': 'Markets',
#            'overall_sentiment_label': 'Neutral',
#            'overall_sentiment_score': 0.122858,
#            'source': 'Benzinga',
#            'source_domain': 'www.benzinga.com',
#            'summary': 'Perplexity AI CEO Aravind Srinivas said on Thursday '
#                       'that "Perplexity will make Apple Intelligence work," '
#                       'responding to a social media post suggesting the '
#                       'artificial intelligence startup should replace Siri on '
#                       'iPhones. What Happened: The comment comes as Apple Inc.',
#            'ticker_sentiment': [{'relevance_score': '0.212115',
#                                  'ticker': 'MSFT',
#                                  'ticker_sentiment_label': 'Neutral',
#                                  'ticker_sentiment_score': '0.103467'},
#                                 {'relevance_score': '0.212115',
#                                  'ticker': 'GOOG',
#                                  'ticker_sentiment_label': 'Neutral',
#                                  'ticker_sentiment_score': '0.103467'},
#                                 {'relevance_score': '0.212115',
#                                  'ticker': 'META',
#                                  'ticker_sentiment_label': 'Neutral',
#                                  'ticker_sentiment_score': '0.103467'},
#                                 {'relevance_score': '0.212115',
#                                  'ticker': 'NVDA',
#                                  'ticker_sentiment_label': 'Somewhat-Bullish',
#                                  'ticker_sentiment_score': '0.343128'},
#                                 {'relevance_score': '0.653656',
#                                  'ticker': 'AAPL',
#                                  'ticker_sentiment_label': 'Bullish',
#                                  'ticker_sentiment_score': '0.439841'},
#                                 {'relevance_score': '0.107016',
#                                  'ticker': 'MS',
#                                  'ticker_sentiment_label': 'Somewhat-Bearish',
#                                  'ticker_sentiment_score': '-0.309175'},
#                                 {'relevance_score': '0.107016',
#                                  'ticker': 'SFBQF',
#                                  'ticker_sentiment_label': 'Somewhat-Bullish',
#                                  'ticker_sentiment_score': '0.234491'},
#                                 {'relevance_score': '0.107016',
#                                  'ticker': 'SFTBF',
#                                  'ticker_sentiment_label': 'Somewhat-Bullish',
#                                  'ticker_sentiment_score': '0.234491'}],
#            'time_published': '20250321T034527',
#            'title': "Perplexity Can Make 'Apple Intelligence Work' Says CEO "
#                     'Aravind Srinivas As iPhone Maker Attracts Criticism On '
#                     'Siri And AI Delays - Apple  ( NASDAQ:AAPL ) , Amazon.com  '
#                     '( NASDAQ:AMZN ) ',
#            'topics': [{'relevance_score': '0.108179',
#                        'topic': 'Financial Markets'},
#                       {'relevance_score': '0.333333', 'topic': 'Manufacturing'},
#                       {'relevance_score': '0.333333', 'topic': 'Technology'},
#                       {'relevance_score': '0.333333', 'topic': 'Finance'}],
#            'url': 'https://www.benzinga.com/25/03/44429645/perplexity-ceo-says-app-will-make-apple-intelligence-work-amid-iphone-makers-ai-challenges'},
#           {'authors': ['Ananya Gairola'],
#            'banner_image': 'https://cdn.benzinga.com/files/images/story/2025/03/20/Leaker-Claims-Apples-Next-Gen-C2-Modem-I.jpeg?width=1200&height=800&fit=crop',
#            'category_within_source': 'News',
#            'overall_sentiment_label': 'Neutral',
#            'overall_sentiment_score': 0.004886,
#            'source': 'Benzinga',
#            'source_domain': 'www.benzinga.com',
#            'summary': 'Apple Inc. AAPL has been facing mounting pressure from '
#                       'investors and competitors. On Thursday, CEO Tim Cook '
#                       'reportedly reshuffled its AI leadership to revive the '
#                       'struggling Siri assistant and catch up in the '
#                       'generative AI race.',
#            'ticker_sentiment': [{'relevance_score': '0.220809',
#                                  'ticker': 'MSFT',
#                                  'ticker_sentiment_label': 'Somewhat-Bullish',
#                                  'ticker_sentiment_score': '0.160157'},
#                                 {'relevance_score': '0.220809',
#                                  'ticker': 'GOOG',
#                                  'ticker_sentiment_label': 'Somewhat-Bullish',
#                                  'ticker_sentiment_score': '0.160157'},
#                                 {'relevance_score': '0.59972',
#                                  'ticker': 'AAPL',
#                                  'ticker_sentiment_label': 'Neutral',
#                                  'ticker_sentiment_score': '-0.068259'},
#                                 {'relevance_score': '0.111488',
#                                  'ticker': 'MS',
#                                  'ticker_sentiment_label': 'Bearish',
#                                  'ticker_sentiment_score': '-0.431609'}],
#            'time_published': '20250321T014536',
#            'title': 'Apple Stock Down Over 12% This Year - Now Tim Cook Is '
#                     "Reportedly Betting On Vision Pro's Mike Rockwell To Fix "
#                     'Siri After Losing Confidence In AI Boss John Giannandrea '
#                     '- Alphabet  ( NASDAQ:GOOG ) , Apple  ( NASDAQ:AAPL ) ',
#            'topics': [{'relevance_score': '0.5', 'topic': 'Technology'},
#                       {'relevance_score': '0.5', 'topic': 'Finance'},
#                       {'relevance_score': '0.214378',
#                        'topic': 'Financial Markets'}],
#            'url': 'https://www.benzinga.com/media/25/03/44429160/apple-stock-down-over-12-this-year-now-tim-cook-is-reportedly-betting-on-vision-pros-mike-rockwell-to-fix-s'},
#           {'authors': ['Zacks Equity Research'],
#            'banner_image': 'https://staticx-tuner.zacks.com/images/default_article_images/default183.jpg',
#            'category_within_source': 'n/a',
#            'overall_sentiment_label': 'Neutral',
#            'overall_sentiment_score': 0.113311,
#            'source': 'Zacks Commentary',
#            'source_domain': 'www.zacks.com',
#            'summary': 'In the latest trading session, Apple (AAPL) closed at '
#                       '$214.10, marking a -0.53% move from the previous day.',
#            'ticker_sentiment': [{'relevance_score': '0.610329',
#                                  'ticker': 'AAPL',
#                                  'ticker_sentiment_label': 'Somewhat-Bullish',
#                                  'ticker_sentiment_score': '0.230596'}],
#            'time_published': '20250320T214515',
#            'title': 'Apple  ( AAPL )  Dips More Than Broader Market: What You '
#                     'Should Know',
#            'topics': [{'relevance_score': '0.938793', 'topic': 'Earnings'},
#                       {'relevance_score': '1.0', 'topic': 'Technology'},
#                       {'relevance_score': '0.161647',
#                        'topic': 'Financial Markets'}],
#            'url': 'https://www.zacks.com/stock/news/2433087/apple-aapl-dips-more-than-broader-market-what-you-should-know'},
#           {'authors': ['Mark Vickery'],
#            'banner_image': 'https://staticx-tuner.zacks.com/images/articles/main/ad/429.jpg',
#            'category_within_source': 'n/a',
#            'overall_sentiment_label': 'Somewhat-Bullish',
#            'overall_sentiment_score': 0.266179,
#            'source': 'Zacks Commentary',
#            'source_domain': 'www.zacks.com',
#            'summary': "Today's Research Daily features new research reports on "
#                       '16 major stocks, including Apple Inc. (AAPL), Meta '
#                       'Platforms, Inc. (META) and Chevron Corporation (CVX), '
#                       'as well as two micro-cap stocks Taylor Devices, Inc. '
#                       '(TAYD) and GSI Technology, Inc. (GSIT).',
#            'ticker_sentiment': [{'relevance_score': '0.129052',
#                                  'ticker': 'META',
#                                  'ticker_sentiment_label': 'Bullish',
#                                  'ticker_sentiment_score': '0.370872'},
#                                 {'relevance_score': '0.213423',
#                                  'ticker': 'AAPL',
#                                  'ticker_sentiment_label': 'Somewhat-Bullish',
#                                  'ticker_sentiment_score': '0.211092'},
#                                 {'relevance_score': '0.043186',
#                                  'ticker': 'GSIT',
#                                  'ticker_sentiment_label': 'Neutral',
#                                  'ticker_sentiment_score': '0.090977'},
#                                 {'relevance_score': '0.043186',
#                                  'ticker': 'HES',
#                                  'ticker_sentiment_label': 'Neutral',
#                                  'ticker_sentiment_score': '-0.019835'},
#                                 {'relevance_score': '0.086245',
#                                  'ticker': 'TAYD',
#                                  'ticker_sentiment_label': 'Neutral',
#                                  'ticker_sentiment_score': '0.063321'}],
#            'time_published': '20250320T213400',
#            'title': 'Top Research Reports for Apple, Meta Platforms & Chevron',
#            'topics': [{'relevance_score': '0.333333', 'topic': 'Manufacturing'},
#                       {'relevance_score': '0.744043', 'topic': 'Earnings'},
#                       {'relevance_score': '0.333333',
#                        'topic': 'Energy & Transportation'},
#                       {'relevance_score': '0.333333', 'topic': 'Technology'}],
#            'url': 'https://www.zacks.com/research-daily/2432978/top-research-reports-for-apple-meta-platforms-chevron'},
#           {'authors': ['The Arora Report'],
#            'banner_image': 'https://thearorareport.com/wp-content/uploads/2025/03/2025-03-20_08h09_57.jpg',
#            'category_within_source': 'Markets',
#            'overall_sentiment_label': 'Somewhat-Bullish',
#            'overall_sentiment_score': 0.195324,
#            'source': 'Benzinga',
#            'source_domain': 'www.benzinga.com',
#            'summary': 'To gain an edge, this is what you need to know today. '
#                       'Please click here for an enlarged chart comparing '
#                       'Nasdaq 100 ETF Invesco QQQ Trust Series 1 ( QQQ ) to '
#                       'European financials ETF iShares MSCI Europe Financials '
#                       'ETF ( EUFN ) . When 2025 started, investors were '
#                       'rushing headlong to buy ...',
#            'ticker_sentiment': [{'relevance_score': '0.075754',
#                                  'ticker': 'MSFT',
#                                  'ticker_sentiment_label': 'Neutral',
#                                  'ticker_sentiment_score': '-0.114241'},
#                                 {'relevance_score': '0.075754',
#                                  'ticker': 'GOOG',
#                                  'ticker_sentiment_label': 'Neutral',
#                                  'ticker_sentiment_score': '-0.114241'},
#                                 {'relevance_score': '0.075754',
#                                  'ticker': 'META',
#                                  'ticker_sentiment_label': 'Neutral',
#                                  'ticker_sentiment_score': '-0.114241'},
#                                 {'relevance_score': '0.113418',
#                                  'ticker': 'NVDA',
#                                  'ticker_sentiment_label': 'Neutral',
#                                  'ticker_sentiment_score': '0.030676'},
#                                 {'relevance_score': '0.075754',
#                                  'ticker': 'AAPL',
#                                  'ticker_sentiment_label': 'Neutral',
#                                  'ticker_sentiment_score': '-0.114241'},
#                                 {'relevance_score': '0.075754',
#                                  'ticker': 'TSLA',
#                                  'ticker_sentiment_label': 'Neutral',
#                                  'ticker_sentiment_score': '-0.114241'},
#                                 {'relevance_score': '0.075754',
#                                  'ticker': 'QBTS',
#                                  'ticker_sentiment_label': 'Neutral',
#                                  'ticker_sentiment_score': '0.0'},
#                                 {'relevance_score': '0.075754',
#                                  'ticker': 'IONQ',
#                                  'ticker_sentiment_label': 'Neutral',
#                                  'ticker_sentiment_score': '0.0'},
#                                 {'relevance_score': '0.03792',
#                                  'ticker': 'IVZ',
#                                  'ticker_sentiment_label': 'Somewhat-Bullish',
#                                  'ticker_sentiment_score': '0.15724'},
#                                 {'relevance_score': '0.075754',
#                                  'ticker': 'RGTI',
#                                  'ticker_sentiment_label': 'Neutral',
#                                  'ticker_sentiment_score': '0.0'},
#                                 {'relevance_score': '0.03792',
#                                  'ticker': 'CRYPTO:BTC',
#                                  'ticker_sentiment_label': 'Neutral',
#                                  'ticker_sentiment_score': '0.0'}],
#            'time_published': '20250320T165958',
#            'title': "Nvidia's First Quantum Computing Day, $4.5T Quad "
#                     'Witching, European Banks Beat Tech Stocks By 34%',
#            'topics': [{'relevance_score': '0.158519',
#                        'topic': 'Economy - Monetary'},
#                       {'relevance_score': '1.0', 'topic': 'Financial Markets'},
#                       {'relevance_score': '0.25', 'topic': 'Manufacturing'},
#                       {'relevance_score': '0.25',
#                        'topic': 'Real Estate & Construction'},
#                       {'relevance_score': '0.25', 'topic': 'Technology'},
#                       {'relevance_score': '0.25', 'topic': 'Finance'}],
#            'url': 'https://www.benzinga.com/markets/equities/25/03/44421496/nvidias-first-quantum-computing-day-4-5t-quad-witching-european-banks-beat-tech-stocks-by-34'},
#           {'authors': ['Benzinga Insights'],
#            'banner_image': 'https://www.benzinga.com/files/images/story/2025/1742482848_0.png',
#            'category_within_source': 'Trading',
#            'overall_sentiment_label': 'Somewhat-Bullish',
#            'overall_sentiment_score': 0.251997,
#            'source': 'Benzinga',
#            'source_domain': 'www.benzinga.com',
#            'summary': 'In the dynamic and fiercely competitive business '
#                       'environment, conducting a thorough analysis of '
#                       'companies is crucial for investors and industry '
#                       'enthusiasts. In this article, we will perform an '
#                       'extensive industry comparison, evaluating Apple AAPL in '
#                       'relation to its major competitors in the ...',
#            'ticker_sentiment': [{'relevance_score': '0.465901',
#                                  'ticker': 'AAPL',
#                                  'ticker_sentiment_label': 'Somewhat-Bullish',
#                                  'ticker_sentiment_score': '0.311403'}],
#            'time_published': '20250320T150052',
#            'title': "Understanding Apple's Position In Technology Hardware, "
#                     'Storage & Peripherals Industry Compared To Competitors - '
#                     'Apple  ( NASDAQ:AAPL ) ',
#            'topics': [{'relevance_score': '0.875462', 'topic': 'Earnings'},
#                       {'relevance_score': '1.0', 'topic': 'Technology'},
#                       {'relevance_score': '0.5855',
#                        'topic': 'Financial Markets'}],
#            'url': 'https://www.benzinga.com/insights/news/25/03/44419038/understanding-apples-position-in-technology-hardware-storage-amp-peripherals-industry-compared-to-c'},
#           {'authors': ['RIPS'],
#            'banner_image': 'https://cdn.benzinga.com/files/images/story/2025/03/20/Gemini-Generated-Image-5kgh255kgh255kgh.jpeg?width=1200&height=800&fit=crop',
#            'category_within_source': 'Trading',
#            'overall_sentiment_label': 'Somewhat-Bullish',
#            'overall_sentiment_score': 0.223752,
#            'source': 'Benzinga',
#            'source_domain': 'www.benzinga.com',
#            'summary': "Good Morning Traders! In today's Market Clubhouse "
#                       'Morning Memo, we will discuss SPY, QQQ, AAPL, MSFT, '
#                       'NVDA, GOOGL, META, and TSLA. Our proprietary formula, '
#                       'exclusive to Market Clubhouse, dictates these price '
#                       'levels. This dynamic equation takes into account price, '
#                       'volume, and options flow.',
#            'ticker_sentiment': [{'relevance_score': '0.08687',
#                                  'ticker': 'MSFT',
#                                  'ticker_sentiment_label': 'Neutral',
#                                  'ticker_sentiment_score': '0.139446'},
#                                 {'relevance_score': '0.029008',
#                                  'ticker': 'GOOG',
#                                  'ticker_sentiment_label': 'Neutral',
#                                  'ticker_sentiment_score': '0.073997'},
#                                 {'relevance_score': '0.08687',
#                                  'ticker': 'NVDA',
#                                  'ticker_sentiment_label': 'Somewhat-Bullish',
#                                  'ticker_sentiment_score': '0.2376'},
#                                 {'relevance_score': '0.08687',
#                                  'ticker': 'AAPL',
#                                  'ticker_sentiment_label': 'Neutral',
#                                  'ticker_sentiment_score': '0.145745'},
#                                 {'relevance_score': '0.115648',
#                                  'ticker': 'TSLA',
#                                  'ticker_sentiment_label': 'Somewhat-Bullish',
#                                  'ticker_sentiment_score': '0.153974'}],
#            'time_published': '20250320T125602',
#            'title': 'How To Trade SPY Ahead Of Triple Witching? - SPDR S&P '
#                     '500  ( ARCA:SPY ) ',
#            'topics': [{'relevance_score': '0.310843',
#                        'topic': 'Economy - Monetary'},
#                       {'relevance_score': '0.999365',
#                        'topic': 'Financial Markets'},
#                       {'relevance_score': '0.5', 'topic': 'Manufacturing'},
#                       {'relevance_score': '0.5', 'topic': 'Technology'}],
#            'url': 'https://www.benzinga.com/markets/equities/25/03/44415917/how-to-trade-spy-ahead-of-triple-witching-as-market-digests-fed-decision'},
#           {'authors': ['Jake Lerch'],
#            'banner_image': 'https://g.foolcdn.com/image/?url=https%3A%2F%2Fg.foolcdn.com%2Feditorial%2Fimages%2F810422%2Fspot-spotify-meta-meta-platforms-stock-market-investment.jpg&op=resize&w=700',
#            'category_within_source': 'n/a',
#            'overall_sentiment_label': 'Bullish',
#            'overall_sentiment_score': 0.380324,
#            'source': 'Motley Fool',
#            'source_domain': 'www.fool.com',
#            'summary': 'They say a rising tide lifts all boats. Well, the '
#                       'reverse is true, too: A falling tide lowers all boats. '
#                       'As it is in the water, so it is in the stock market. '
#                       'Case in point: As of this writing, the tech-heavy '
#                       'Nasdaq Composite ( NASDAQINDEX: ^IXIC ) has fallen by '
#                       'more than 9% year to date.',
#            'ticker_sentiment': [{'relevance_score': '0.072217',
#                                  'ticker': 'NFLX',
#                                  'ticker_sentiment_label': 'Somewhat-Bullish',
#                                  'ticker_sentiment_score': '0.158388'},
#                                 {'relevance_score': '0.214304',
#                                  'ticker': 'META',
#                                  'ticker_sentiment_label': 'Neutral',
#                                  'ticker_sentiment_score': '0.140183'},
#                                 {'relevance_score': '0.072217',
#                                  'ticker': 'NVDA',
#                                  'ticker_sentiment_label': 'Neutral',
#                                  'ticker_sentiment_score': '-0.038765'},
#                                 {'relevance_score': '0.072217',
#                                  'ticker': 'AAPL',
#                                  'ticker_sentiment_label': 'Neutral',
#                                  'ticker_sentiment_score': '-0.038765'},
#                                 {'relevance_score': '0.413425',
#                                  'ticker': 'SPOT',
#                                  'ticker_sentiment_label': 'Bullish',
#                                  'ticker_sentiment_score': '0.513525'}],
#            'time_published': '20250320T121000',
#            'title': '2 Leading Tech Stocks to Buy in 2025',
#            'topics': [{'relevance_score': '0.990999',
#                        'topic': 'Financial Markets'},
#                       {'relevance_score': '0.5', 'topic': 'Manufacturing'},
#                       {'relevance_score': '0.938793', 'topic': 'Earnings'},
#                       {'relevance_score': '0.5', 'topic': 'Technology'}],
#            'url': 'https://www.fool.com/investing/2025/03/20/2-leading-tech-stocks-to-buy-in-2025/'},
#           {'authors': ['Zacks Equity Research'],
#            'banner_image': 'https://staticx-tuner.zacks.com/images/default_article_images/default40.jpg',
#            'category_within_source': 'n/a',
#            'overall_sentiment_label': 'Somewhat-Bullish',
#            'overall_sentiment_score': 0.166312,
#            'source': 'Zacks Commentary',
#            'source_domain': 'www.zacks.com',
#            'summary': 'Style Box ETF report for VOTE ...',
#            'ticker_sentiment': [{'relevance_score': '0.138066',
#                                  'ticker': 'MSFT',
#                                  'ticker_sentiment_label': 'Neutral',
#                                  'ticker_sentiment_score': '0.072464'},
#                                 {'relevance_score': '0.138066',
#                                  'ticker': 'NVDA',
#                                  'ticker_sentiment_label': 'Neutral',
#                                  'ticker_sentiment_score': '0.072464'},
#                                 {'relevance_score': '0.138066',
#                                  'ticker': 'AAPL',
#                                  'ticker_sentiment_label': 'Neutral',
#                                  'ticker_sentiment_score': '0.072464'},
#                                 {'relevance_score': '0.069294',
#                                  'ticker': 'MORN',
#                                  'ticker_sentiment_label': 'Neutral',
#                                  'ticker_sentiment_score': '0.0'}],
#            'time_published': '20250320T102006',
#            'title': 'Should TCW Transform 500 ETF  ( VOTE )  Be on Your '
#                     'Investing Radar?',
#            'topics': [{'relevance_score': '1.0', 'topic': 'Financial Markets'},
#                       {'relevance_score': '0.333333', 'topic': 'Manufacturing'},
#                       {'relevance_score': '0.333333', 'topic': 'Technology'},
#                       {'relevance_score': '0.333333', 'topic': 'Finance'}],
#            'url': 'https://www.zacks.com/stock/news/2432524/should-tcw-transform-500-etf-vote-be-on-your-investing-radar'},
#           {'authors': ['Zacks Equity Research'],
#            'banner_image': 'https://staticx-tuner.zacks.com/images/default_article_images/default335.jpg',
#            'category_within_source': 'n/a',
#            'overall_sentiment_label': 'Somewhat-Bullish',
#            'overall_sentiment_score': 0.258295,
#            'source': 'Zacks Commentary',
#            'source_domain': 'www.zacks.com',
#            'summary': 'Style Box ETF report for VUG ...',
#            'ticker_sentiment': [{'relevance_score': '0.122581',
#                                  'ticker': 'MSFT',
#                                  'ticker_sentiment_label': 'Neutral',
#                                  'ticker_sentiment_score': '0.068387'},
#                                 {'relevance_score': '0.122581',
#                                  'ticker': 'NVDA',
#                                  'ticker_sentiment_label': 'Neutral',
#                                  'ticker_sentiment_score': '0.068387'},
#                                 {'relevance_score': '0.122581',
#                                  'ticker': 'AAPL',
#                                  'ticker_sentiment_label': 'Neutral',
#                                  'ticker_sentiment_score': '0.068387'},
#                                 {'relevance_score': '0.122581',
#                                  'ticker': 'IVZ',
#                                  'ticker_sentiment_label': 'Neutral',
#                                  'ticker_sentiment_score': '0.096685'}],
#            'time_published': '20250320T102006',
#            'title': 'Should Vanguard Growth ETF  ( VUG )  Be on Your Investing '
#                     'Radar?',
#            'topics': [{'relevance_score': '0.999998',
#                        'topic': 'Financial Markets'},
#                       {'relevance_score': '0.333333', 'topic': 'Manufacturing'},
#                       {'relevance_score': '0.310843', 'topic': 'Earnings'},
#                       {'relevance_score': '0.333333', 'topic': 'Technology'},
#                       {'relevance_score': '0.333333', 'topic': 'Finance'}],
#            'url': 'https://www.zacks.com/stock/news/2432525/should-vanguard-growth-etf-vug-be-on-your-investing-radar'},
#           {'authors': ['Zacks Equity Research'],
#            'banner_image': 'https://staticx-tuner.zacks.com/images/default_article_images/default91.jpg',
#            'category_within_source': 'n/a',
#            'overall_sentiment_label': 'Somewhat-Bullish',
#            'overall_sentiment_score': 0.190657,
#            'source': 'Zacks Commentary',
#            'source_domain': 'www.zacks.com',
#            'summary': 'Smart Beta ETF report for TILT ...',
#            'ticker_sentiment': [{'relevance_score': '0.108712',
#                                  'ticker': 'MSFT',
#                                  'ticker_sentiment_label': 'Neutral',
#                                  'ticker_sentiment_score': '0.042368'},
#                                 {'relevance_score': '0.108712',
#                                  'ticker': 'NVDA',
#                                  'ticker_sentiment_label': 'Neutral',
#                                  'ticker_sentiment_score': '0.042368'},
#                                 {'relevance_score': '0.108712',
#                                  'ticker': 'AAPL',
#                                  'ticker_sentiment_label': 'Neutral',
#                                  'ticker_sentiment_score': '0.042368'},
#                                 {'relevance_score': '0.215415',
#                                  'ticker': 'MORN',
#                                  'ticker_sentiment_label': 'Neutral',
#                                  'ticker_sentiment_score': '0.140751'}],
#            'time_published': '20250320T102006',
#            'title': 'Is FlexShares Morningstar U.S. Market Factor Tilt ETF  ( '
#                     'TILT )  a Strong ETF Right Now?',
#            'topics': [{'relevance_score': '1.0', 'topic': 'Financial Markets'},
#                       {'relevance_score': '0.333333', 'topic': 'Manufacturing'},
#                       {'relevance_score': '0.333333', 'topic': 'Technology'},
#                       {'relevance_score': '0.333333', 'topic': 'Finance'}],
#            'url': 'https://www.zacks.com/stock/news/2432527/is-flexshares-morningstar-us-market-factor-tilt-etf-tilt-a-strong-etf-right-now'},
#           {'authors': ['Zacks Equity Research'],
#            'banner_image': 'https://staticx-tuner.zacks.com/images/default_article_images/default257.jpg',
#            'category_within_source': 'n/a',
#            'overall_sentiment_label': 'Somewhat-Bullish',
#            'overall_sentiment_score': 0.236116,
#            'source': 'Zacks Commentary',
#            'source_domain': 'www.zacks.com',
#            'summary': 'Smart Beta ETF report for ...',
#            'ticker_sentiment': [{'relevance_score': '0.111747',
#                                  'ticker': 'MSFT',
#                                  'ticker_sentiment_label': 'Neutral',
#                                  'ticker_sentiment_score': '0.042777'},
#                                 {'relevance_score': '0.111747',
#                                  'ticker': 'NVDA',
#                                  'ticker_sentiment_label': 'Neutral',
#                                  'ticker_sentiment_score': '0.042777'},
#                                 {'relevance_score': '0.111747',
#                                  'ticker': 'AAPL',
#                                  'ticker_sentiment_label': 'Neutral',
#                                  'ticker_sentiment_score': '0.042777'},
#                                 {'relevance_score': '0.111747',
#                                  'ticker': 'NTRS',
#                                  'ticker_sentiment_label': 'Somewhat-Bullish',
#                                  'ticker_sentiment_score': '0.151179'}],
#            'time_published': '20250320T102005',
#            'title': 'Is FlexShares US Quality Large Cap ETF  ( QLC )  a Strong '
#                     'ETF Right Now?',
#            'topics': [{'relevance_score': '1.0', 'topic': 'Financial Markets'},
#                       {'relevance_score': '0.333333', 'topic': 'Manufacturing'},
#                       {'relevance_score': '0.333333', 'topic': 'Technology'},
#                       {'relevance_score': '0.333333', 'topic': 'Finance'}],
#            'url': 'https://www.zacks.com/stock/news/2432535/is-flexshares-us-quality-large-cap-etf-qlc-a-strong-etf-right-now'},
#           {'authors': ['Neil Patel'],
#            'banner_image': 'https://g.foolcdn.com/editorial/images/811316/using-iphone-at-desk-with-apple-watch-on.jpg',
#            'category_within_source': 'n/a',
#            'overall_sentiment_label': 'Somewhat-Bullish',
#            'overall_sentiment_score': 0.304995,
#            'source': 'Motley Fool',
#            'source_domain': 'www.fool.com',
#            'summary': 'Every investor has heard of Apple ( NASDAQ: AAPL ) . '
#                       'The consumer tech juggernaut has worked out to be a '
#                       'fantastic investment. Its share price has catapulted a '
#                       'jaw-dropping 14,460% in the past 20 years ( as of March '
#                       '17 ) .',
#            'ticker_sentiment': [{'relevance_score': '0.600602',
#                                  'ticker': 'AAPL',
#                                  'ticker_sentiment_label': 'Bullish',
#                                  'ticker_sentiment_score': '0.539732'}],
#            'time_published': '20250320T100500',
#            'title': 'Could Buying Apple Today Set You Up for Life?',
#            'topics': [{'relevance_score': '0.818451', 'topic': 'Earnings'},
#                       {'relevance_score': '1.0', 'topic': 'Technology'},
#                       {'relevance_score': '0.684621',
#                        'topic': 'Financial Markets'}],
#            'url': 'https://www.fool.com/investing/2025/03/20/could-buying-apple-today-set-you-up-for-life/'},
#           {'authors': ['Lawrence Nga'],
#            'banner_image': 'https://g.foolcdn.com/image/?url=https%3A%2F%2Fg.foolcdn.com%2Feditorial%2Fimages%2F811426%2Fai-6.jpg&op=resize&w=700',
#            'category_within_source': 'n/a',
#            'overall_sentiment_label': 'Somewhat-Bullish',
#            'overall_sentiment_score': 0.254287,
#            'source': 'Motley Fool',
#            'source_domain': 'www.fool.com',
#            'summary': 'Alibaba is set for better times in 2025 and beyond.',
#            'ticker_sentiment': [{'relevance_score': '0.419927',
#                                  'ticker': 'BABA',
#                                  'ticker_sentiment_label': 'Somewhat-Bullish',
#                                  'ticker_sentiment_score': '0.329112'},
#                                 {'relevance_score': '0.049019',
#                                  'ticker': 'AAPL',
#                                  'ticker_sentiment_label': 'Neutral',
#                                  'ticker_sentiment_score': '0.035858'}],
#            'time_published': '20250320T091500',
#            'title': 'Up Over 50% in 2025, Is Alibaba Stock a Buy Now?',
#            'topics': [{'relevance_score': '0.161647', 'topic': 'Earnings'},
#                       {'relevance_score': '1.0', 'topic': 'Technology'},
#                       {'relevance_score': '0.929393',
#                        'topic': 'Financial Markets'}],
#            'url': 'https://www.fool.com/investing/2025/03/20/up-over-50-in-2025-is-alibaba-stock-a-buy-now/'},
#           {'authors': ['Ananya Gairola'],
#            'banner_image': 'https://cdn.benzinga.com/files/images/story/2025/03/20/Price-Action.jpeg?width=1200&height=800&fit=crop',
#            'category_within_source': 'News',
#            'overall_sentiment_label': 'Neutral',
#            'overall_sentiment_score': 0.043185,
#            'source': 'Benzinga',
#            'source_domain': 'www.benzinga.com',
#            'summary': 'Eric Migicovsky, the creator of the original Pebble '
#                       "smartwatch, has said Apple Inc.'s AAPL iOS restrictions "
#                       'stifle innovation and make building third-party '
#                       'wearables a painful uphill battle.',
#            'ticker_sentiment': [{'relevance_score': '0.074001',
#                                  'ticker': 'GOOG',
#                                  'ticker_sentiment_label': 'Neutral',
#                                  'ticker_sentiment_score': '-0.010166'},
#                                 {'relevance_score': '0.147366',
#                                  'ticker': 'META',
#                                  'ticker_sentiment_label': 'Neutral',
#                                  'ticker_sentiment_score': '-0.14086'},
#                                 {'relevance_score': '0.542539',
#                                  'ticker': 'AAPL',
#                                  'ticker_sentiment_label': 'Neutral',
#                                  'ticker_sentiment_score': '0.006738'}],
#            'time_published': '20250320T091313',
#            'title': "Pebble Founder Echoes Mark Zuckerberg's Concerns, Slams "
#                     "Apple For Making It 'Nearly Impossible' To Build "
# ...
#                       "its all-time high, it's now in correction territory. "
#                       'While nobody likes seeing their holdings decline by 10% '
#                       'or more, corrections occur about every year, so nobody '
#                       'should be surprised when they happen.',
#            'ticker_sentiment': [{'relevance_score': '0.113597',
#                                  'ticker': 'NVDA',
#                                  'ticker_sentiment_label': 'Neutral',
#                                  'ticker_sentiment_score': '0.044141'},
#                                 {'relevance_score': '0.056943',
#                                  'ticker': 'AAPL',
#                                  'ticker_sentiment_label': 'Neutral',
#                                  'ticker_sentiment_score': '0.039943'}],
#            'time_published': '20250318T110000',
#            'title': "S&P 500 Correction: 1 Incredible AI Stock That I'm Buying "
#                     'Now and Holding Forever',
#            'topics': [{'relevance_score': '0.998356',
#                        'topic': 'Financial Markets'},
#                       {'relevance_score': '0.5', 'topic': 'Manufacturing'},
#                       {'relevance_score': '0.650727', 'topic': 'Earnings'},
#                       {'relevance_score': '0.5', 'topic': 'Technology'}],
#            'url': 'https://www.fool.com/investing/2025/03/18/1-incredible-ai-stock-that-im-buying-now-and-holdi/'},
#           {'authors': ['Zacks Equity Research'],
#            'banner_image': 'https://staticx-tuner.zacks.com/images/default_article_images/default137.jpg',
#            'category_within_source': 'n/a',
#            'overall_sentiment_label': 'Somewhat-Bullish',
#            'overall_sentiment_score': 0.224695,
#            'source': 'Zacks Commentary',
#            'source_domain': 'www.zacks.com',
#            'summary': 'Smart Beta ETF report for ...',
#            'ticker_sentiment': [{'relevance_score': '0.11123',
#                                  'ticker': 'MSFT',
#                                  'ticker_sentiment_label': 'Neutral',
#                                  'ticker_sentiment_score': '0.065797'},
#                                 {'relevance_score': '0.11123',
#                                  'ticker': 'NVDA',
#                                  'ticker_sentiment_label': 'Neutral',
#                                  'ticker_sentiment_score': '0.065797'},
#                                 {'relevance_score': '0.11123',
#                                  'ticker': 'AAPL',
#                                  'ticker_sentiment_label': 'Neutral',
#                                  'ticker_sentiment_score': '0.065797'}],
#            'time_published': '20250318T102007',
#            'title': 'Is iShares Paris-Aligned Climate MSCI USA ETF  ( PABU )  '
#                     'a Strong ETF Right Now?',
#            'topics': [{'relevance_score': '0.5', 'topic': 'Technology'},
#                       {'relevance_score': '0.99999',
#                        'topic': 'Financial Markets'},
#                       {'relevance_score': '0.5', 'topic': 'Manufacturing'}],
#            'url': 'https://www.zacks.com/stock/news/2431187/is-ishares-paris-aligned-climate-msci-usa-etf-pabu-a-strong-etf-right-now'},
#           {'authors': ['Zacks Equity Research'],
#            'banner_image': 'https://staticx-tuner.zacks.com/images/default_article_images/default39.jpg',
#            'category_within_source': 'n/a',
#            'overall_sentiment_label': 'Somewhat-Bullish',
#            'overall_sentiment_score': 0.258406,
#            'source': 'Zacks Commentary',
#            'source_domain': 'www.zacks.com',
#            'summary': 'Style Box ETF report for ...',
#            'ticker_sentiment': [{'relevance_score': '0.124164',
#                                  'ticker': 'MSFT',
#                                  'ticker_sentiment_label': 'Neutral',
#                                  'ticker_sentiment_score': '0.068777'},
#                                 {'relevance_score': '0.124164',
#                                  'ticker': 'NVDA',
#                                  'ticker_sentiment_label': 'Neutral',
#                                  'ticker_sentiment_score': '0.068777'},
#                                 {'relevance_score': '0.124164',
#                                  'ticker': 'AAPL',
#                                  'ticker_sentiment_label': 'Neutral',
#                                  'ticker_sentiment_score': '0.068777'},
#                                 {'relevance_score': '0.062271',
#                                  'ticker': 'STT',
#                                  'ticker_sentiment_label': 'Neutral',
#                                  'ticker_sentiment_score': '0.115039'},
#                                 {'relevance_score': '0.124164',
#                                  'ticker': 'IVZ',
#                                  'ticker_sentiment_label': 'Neutral',
#                                  'ticker_sentiment_score': '0.104504'}],
#            'time_published': '20250318T102006',
#            'title': 'Should SPDR Portfolio S&P 500 Growth ETF  ( SPYG )  Be on '
#                     'Your Investing Radar?',
#            'topics': [{'relevance_score': '1.0', 'topic': 'Financial Markets'},
#                       {'relevance_score': '0.333333', 'topic': 'Manufacturing'},
#                       {'relevance_score': '0.310843', 'topic': 'Earnings'},
#                       {'relevance_score': '0.333333', 'topic': 'Technology'},
#                       {'relevance_score': '0.333333', 'topic': 'Finance'}],
#            'url': 'https://www.zacks.com/stock/news/2431189/should-spdr-portfolio-sp-500-growth-etf-spyg-be-on-your-investing-radar'},
#           {'authors': ['James Brumley'],
#            'banner_image': 'https://g.foolcdn.com/editorial/images/811255/buffett16-tmf.jpg',
#            'category_within_source': 'n/a',
#            'overall_sentiment_label': 'Neutral',
#            'overall_sentiment_score': 0.144405,
#            'source': 'Motley Fool',
#            'source_domain': 'www.fool.com',
#            'summary': "While stocks as a whole are selling off, there's a "
#                       'reason the Oracle of Omaha is sticking with these '
#                       'beaten-down holdings.',
#            'ticker_sentiment': [{'relevance_score': '0.134779',
#                                  'ticker': 'AXP',
#                                  'ticker_sentiment_label': 'Neutral',
#                                  'ticker_sentiment_score': '0.018037'},
#                                 {'relevance_score': '0.297461',
#                                  'ticker': 'AAPL',
#                                  'ticker_sentiment_label': 'Somewhat-Bullish',
#                                  'ticker_sentiment_score': '0.213047'},
#                                 {'relevance_score': '0.168021',
#                                  'ticker': 'AMZN',
#                                  'ticker_sentiment_label': 'Somewhat-Bullish',
#                                  'ticker_sentiment_score': '0.160498'}],
#            'time_published': '20250318T094500',
#            'title': 'The Best Warren Buffett Stocks to Buy With $2,000 Right '
#                     'Now',
#            'topics': [{'relevance_score': '0.333333',
#                        'topic': 'Retail & Wholesale'},
#                       {'relevance_score': '0.918141',
#                        'topic': 'Financial Markets'},
#                       {'relevance_score': '0.161647', 'topic': 'Earnings'},
#                       {'relevance_score': '0.333333', 'topic': 'Technology'},
#                       {'relevance_score': '0.333333', 'topic': 'Finance'}],
#            'url': 'https://www.fool.com/investing/2025/03/18/the-best-warren-buffett-stocks-to-buy-with-2000-ri/'},
#           {'authors': ['Rishabh Mishra'],
#            'banner_image': 'https://editorial-assets.benzinga.com/wp-content/uploads/2025/03/18035026/Roundhill-since-DeepSeek-1024x576.png',
#            'category_within_source': 'Markets',
#            'overall_sentiment_label': 'Somewhat-Bullish',
#            'overall_sentiment_score': 0.272234,
#            'source': 'Benzinga',
#            'source_domain': 'www.benzinga.com',
#            'summary': 'As the Magnificent 7 companies have estimated a total '
#                       'capital expenditure of over $330 billion on the '
#                       'artificial intelligence infrastructure in 2025, there '
#                       "is a possibility that China's AI breakthrough, despite "
#                       'chip shortage, could affect their targets, affecting '
#                       'profitability.',
#            'ticker_sentiment': [{'relevance_score': '0.207571',
#                                  'ticker': 'META',
#                                  'ticker_sentiment_label': 'Somewhat-Bullish',
#                                  'ticker_sentiment_score': '0.227947'},
#                                 {'relevance_score': '0.207571',
#                                  'ticker': 'NVDA',
#                                  'ticker_sentiment_label': 'Neutral',
#                                  'ticker_sentiment_score': '0.119249'},
#                                 {'relevance_score': '0.207571',
#                                  'ticker': 'AAPL',
#                                  'ticker_sentiment_label': 'Neutral',
#                                  'ticker_sentiment_score': '0.119249'},
#                                 {'relevance_score': '0.104683',
#                                  'ticker': 'IVZ',
#                                  'ticker_sentiment_label': 'Somewhat-Bullish',
#                                  'ticker_sentiment_score': '0.25139'}],
#            'time_published': '20250318T091352',
#            'title': "AI Bubble Bursting? Magnificent 7's Profit Margins Face "
#                     "Pressure As 'Capital Spending Can Tumble' In 2025 - "
#                     'Apple  ( NASDAQ:AAPL ) , Amazon.com  ( NASDAQ:AMZN ) ',
#            'topics': [{'relevance_score': '0.158519',
#                        'topic': 'Economy - Monetary'},
#                       {'relevance_score': '0.875462',
#                        'topic': 'Financial Markets'},
#                       {'relevance_score': '0.333333', 'topic': 'Manufacturing'},
#                       {'relevance_score': '0.158519', 'topic': 'Earnings'},
#                       {'relevance_score': '0.333333', 'topic': 'Technology'},
#                       {'relevance_score': '0.333333', 'topic': 'Finance'}],
#            'url': 'https://www.benzinga.com/markets/equities/25/03/44371661/ai-bubble-bursting-magnificent-7s-profit-margins-face-pressure-as-capital-spending-can-tumble-in'},
#           {'authors': ['Chris Katje'],
#            'banner_image': 'https://cdn.benzinga.com/files/images/story/2025/03/17/What-Apple-Did_5.jpeg?width=1200&height=800&fit=crop',
#            'category_within_source': 'Trading',
#            'overall_sentiment_label': 'Somewhat-Bullish',
#            'overall_sentiment_score': 0.185295,
#            'source': 'Benzinga',
#            'source_domain': 'www.benzinga.com',
#            'summary': 'A foldable iPhone could be coming as early as 2026 '
#                       'according to several reports. Apple has been working on '
#                       'foldable devices for years, says reports. Join Nic '
#                       'Chahine live on Wednesday, March 19, at 6 PM ET for a '
#                       'step-by-step breakdown of how to to capitalize on '
#                       'post-Fed volatility and manage ...',
#            'ticker_sentiment': [{'relevance_score': '0.140485',
#                                  'ticker': 'SSNLF',
#                                  'ticker_sentiment_label': 'Neutral',
#                                  'ticker_sentiment_score': '0.0'},
#                                 {'relevance_score': '0.070517',
#                                  'ticker': 'GOOG',
#                                  'ticker_sentiment_label': 'Neutral',
#                                  'ticker_sentiment_score': '0.0'},
#                                 {'relevance_score': '0.784632',
#                                  'ticker': 'AAPL',
#                                  'ticker_sentiment_label': 'Bullish',
#                                  'ticker_sentiment_score': '0.376997'}],
#            'time_published': '20250317T214835',
#            'title': 'Apple Stock Faces Pressure From Declining iPhone Revenue: '
#                     "Could Company's First Foldable Smartphone In 2026 Reverse "
#                     'Course? - Alphabet  ( NASDAQ:GOOG ) , Apple  ( '
#                     'NASDAQ:AAPL ) ',
#            'topics': [{'relevance_score': '1.0', 'topic': 'Technology'},
#                       {'relevance_score': '0.87644',
#                        'topic': 'Financial Markets'}],
#            'url': 'https://www.benzinga.com/tech/25/03/44366890/apple-stock-faces-pressure-from-declining-iphone-revenue-could-companys-first-foldable-smartphone-in-2026-re'},
#           {'authors': ['Adam Eckert'],
#            'banner_image': 'https://cdn.benzinga.com/files/images/story/2025/03/17/trader-ai7.png?width=1200&height=800&fit=crop',
#            'category_within_source': 'Trading',
#            'overall_sentiment_label': 'Somewhat-Bullish',
#            'overall_sentiment_score': 0.302736,
#            'source': 'Benzinga',
#            'source_domain': 'www.benzinga.com',
#            'summary': 'Renowned trader and chartist Larry Williams believes '
#                       'the market is ready to rally. Williams says Tesla, '
#                       'Nvidia, ASML Holding and Apple shares are flashing '
#                       'bullish signs.',
#            'ticker_sentiment': [{'relevance_score': '0.06211',
#                                  'ticker': 'GOOG',
#                                  'ticker_sentiment_label': 'Neutral',
#                                  'ticker_sentiment_score': '0.121041'},
#                                 {'relevance_score': '0.516883',
#                                  'ticker': 'NVDA',
#                                  'ticker_sentiment_label': 'Bullish',
#                                  'ticker_sentiment_score': '0.427552'},
#                                 {'relevance_score': '0.414559',
#                                  'ticker': 'AAPL',
#                                  'ticker_sentiment_label': 'Somewhat-Bullish',
#                                  'ticker_sentiment_score': '0.338856'},
#                                 {'relevance_score': '0.303175',
#                                  'ticker': 'TSLA',
#                                  'ticker_sentiment_label': 'Bullish',
#                                  'ticker_sentiment_score': '0.478466'},
#                                 {'relevance_score': '0.303175',
#                                  'ticker': 'ASML',
#                                  'ticker_sentiment_label': 'Somewhat-Bullish',
#                                  'ticker_sentiment_score': '0.215532'}],
#            'time_published': '20250317T164730',
#            'title': 'Legendary Trader Says Tesla, Nvidia, Apple Shares Are '
#                     "Ready To Rally: 'I See What I Like To See' - Tesla  ( "
#                     'NASDAQ:TSLA ) ',
#            'topics': [{'relevance_score': '0.5', 'topic': 'Technology'},
#                       {'relevance_score': '0.99793',
#                        'topic': 'Financial Markets'},
#                       {'relevance_score': '0.5', 'topic': 'Manufacturing'}],
#            'url': 'https://www.benzinga.com/trading-ideas/long-ideas/25/03/44360400/legendary-trader-says-tesla-nvidia-apple-shares-are-ready-to-rally-i-see-what-i-like-to-'}],
#  'items': '50',
#  'relevance_score_definition': '0 < x <= 1, with a higher score indicating '
#                                'higher relevance.',
#  'sentiment_score_definition': 'x <= -0.35: Bearish; -0.35 < x <= -0.15: '
#                                'Somewhat-Bearish; -0.15 < x < 0.15: Neutral; '
#                                '0.15 <= x < 0.35: Somewhat_Bullish; x >= 0.35: '
#                                'Bullish'}

# %%
import pandas as pd
df = pd.DataFrame(data)
df.head()
# Out:
#   items                         sentiment_score_definition  \
# 0    50  x <= -0.35: Bearish; -0.35 < x <= -0.15: Somew...
# 1    50  x <= -0.35: Bearish; -0.35 < x <= -0.15: Somew...
# 2    50  x <= -0.35: Bearish; -0.35 < x <= -0.15: Somew...
# 3    50  x <= -0.35: Bearish; -0.35 < x <= -0.15: Somew...
# 4    50  x <= -0.35: Bearish; -0.35 < x <= -0.15: Somew...
#
#                           relevance_score_definition  \
# 0  0 < x <= 1, with a higher score indicating hig...
# 1  0 < x <= 1, with a higher score indicating hig...
# 2  0 < x <= 1, with a higher score indicating hig...
# 3  0 < x <= 1, with a higher score indicating hig...
# 4  0 < x <= 1, with a higher score indicating hig...
#
#                                                 feed
# 0  {'title': 'Jeff Bezos And Nvidia-Backed Perple...
# 1  {'title': 'The Zacks Analyst Blog Highlights A...
# 2  {'title': 'Apple TV+ Bleeding Over $1 Billion ...
# 3  {'title': 'Perplexity Can Make 'Apple Intellig...
# 4  {'title': 'Apple Stock Down Over 12% This Year...

# %%
df.to_parquet('filename.parquet')
df.to_csv('filename.csv')
df.to_excel('filename.xlsx')

# %%
URL = "https://api.example.com/data"
API_KEY = "your_api_key_here"

data = []

loop through every date:
    loop through every page:
        response = request(URL, API_KEY, current_date, current_page)
        if response.status_code == 200:
            data.append(response.json())
